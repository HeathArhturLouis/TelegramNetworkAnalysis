# %% [markdown]
# # Meta Topic Analysis and Topic Data Wrangling

# %%
import pandas as pd
import pickle
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Meta Topic Analysis

# %%
# Load Data For Analysis
with open('drive/MyDrive/AAA/ActiveChats2023-04-03-cleaned.csv' , "r") as file:
    file.readline()
    ch_names = [name.rstrip() for name in file]
    ch_names = list(set(ch_names))

meta_topic_mapping = pd.read_table('drive/MyDrive/LinkedInTheDark/Meta Topics Mapping.tsv')
lab_topics = pd.read_csv('drive/MyDrive/LinkedInTheDark/labelled_topics.csv', index_col=0)
chat_activity_epoch = pd.read_csv('drive/MyDrive/LinkedInTheDark/chat_activity_per_epoch.csv', index_col=0)
chat_activity_epoch = chat_activity_epoch.rename(columns={"Epoch 1": "Epoch 1 Freq", "Epoch 2": "Epoch 2 Freq", "Epoch 3": "Epoch 3 Freq"}, errors="raise")


with open('drive/MyDrive/AAA/topics_per_class.pkl', 'rb') as f:
  topics_per_class = pickle.load(f)


meta_topic_mapping['Topics'] = meta_topic_mapping['Topics'].apply(lambda x : [int(x) for x in set(x.split(sep = ','))] )

# %%
try:
  lab_topics = lab_topics.set_index('Topic')
except:
  pass

# %%
# compute topics and total weight per topic per epoch
lab_topics['Total Incidence'] = np.zeros(len(lab_topics.index))

for col in ["Epoch 1 Incidence", "Epoch 2 Incidence", "Epoch 3 Incidence"]:
  lab_topics[col] = np.zeros(len(lab_topics.index))

for chat in ch_names:
  for epoch in ["Epoch 1", "Epoch 2", "Epoch 3"]:
    index_f = f'./Data/Messages/RawData/chat_{chat}_epoch_{epoch}.csv\n'
    for index, row in topics_per_class[topics_per_class["Class"] == index_f].iterrows():
      # For Each Row / Topic in an Epoch
      lab_topics.loc[row['Topic'], (epoch + ' Incidence')] += row['Frequency']

lab_topics['Total Incidence'] = lab_topics['Epoch 1 Incidence'] + lab_topics['Epoch 2 Incidence'] + lab_topics['Epoch 3 Incidence']

lab_topics
# Out:
#                                                    Words  IsBrit  IsExtremist  \
# Topic
# -1        resistance, britain, uk, group https, joinchat    True         True
#  0        https __, pdf, org web, archive org, pdf https   False        False
#  1     licence, scumbag, young girl, follow ashleasim...    True         True
#  2     white, follow ashleasimonnews, ashleasimonnews...    True         True
#  3             african, immigrants, israel, send, europe   False         True
# ...                                                  ...     ...          ...
#  136            audit, important, contract, smart, trust   False        False
#  43                          tommy, rr, rod, goodbye, np   False        False
#  69                    rape, raped, women, rapist, wrote   False        False
#  138       liberal, liberals, leftists, obvious, leftist   False         True
#  95          grooming, grooming gangs, gangs, stars, pop    True         True
#
#        Total Incidence  Epoch 1 Incidence  Epoch 2 Incidence  \
# Topic
# -1            169761.0            14416.0            55094.0
#  0             57362.0             3707.0            20308.0
#  1              4585.0              734.0             1969.0
#  2              2912.0              260.0             1583.0
#  3              2890.0              239.0             1027.0
# ...                ...                ...                ...
#  136             408.0               14.0               52.0
#  43             1041.0               17.0              675.0
#  69              147.0               30.0               42.0
#  138             241.0               84.0              114.0
#  95              882.0                2.0              160.0
#
#        Epoch 3 Incidence
# Topic
# -1              100251.0
#  0               33347.0
#  1                1882.0
#  2                1069.0
#  3                1624.0
# ...                  ...
#  136               342.0
#  43                349.0
#  69                 75.0
#  138                43.0
#  95                720.0
#
# [140 rows x 7 columns]

# %%
meta_topic_mapping['Total Incidence'] = np.zeros(len(meta_topic_mapping.index))

for col in ["Epoch 1 Incidence", "Epoch 2 Incidence", "Epoch 3 Incidence"]:
  meta_topic_mapping[col] = np.zeros(len(meta_topic_mapping.index))

for index, row in meta_topic_mapping.iterrows():
  for topic_id in row['Topics']:
    meta_topic_mapping.loc[index, 'Total Incidence'] += lab_topics.loc[topic_id, 'Total Incidence']
    meta_topic_mapping.loc[index, 'Epoch 1 Incidence'] += lab_topics.loc[topic_id, 'Epoch 1 Incidence']
    meta_topic_mapping.loc[index, 'Epoch 2 Incidence'] += lab_topics.loc[topic_id,'Epoch 2 Incidence']
    meta_topic_mapping.loc[index, 'Epoch 3 Incidence'] += lab_topics.loc[topic_id,'Epoch 3 Incidence']

meta_topic_mapping
# Out:
#                    Meta Topic Name  \
# 0                         Business
# 1    Cryptocurrencies & Investment
# 2  Technology, Industry & Business
# 3            Covid & Mobile Phones
# 4                   UK, Race, LGBT
# 5             Law & Current Events
# 6  Politics, News & Current Events
#
#                                               Topics  Total Incidence  \
# 0            [93, 65, 73, 60, 33, 124, 100, 98, 125]           1990.0
# 1  [118, 22, 90, 97, 53, 4, 52, 43, 123, 16, 56, 78]           7695.0
# 2  [117, 89, 7, 77, 105, 83, 80, 109, 17, 84, 122...          11946.0
# 3                               [86, 2, 11, 111, 69]           3426.0
# 4  [57, 76, 113, 66, 107, 20, 12, 112, 5, 106, 85...           8796.0
# 5                     [87, 42, 92, 103, 70, 104, 34]           1913.0
# 6  [101, 68, 61, 72, 65, 38, 32, 24, 1, 121, 59, ...          24478.0
#
#    Epoch 1 Incidence  Epoch 2 Incidence  Epoch 3 Incidence
# 0              305.0              853.0              832.0
# 1              747.0             3459.0             3489.0
# 2             1143.0             6444.0             4359.0
# 3              313.0             1757.0             1356.0
# 4             1016.0             3800.0             3980.0
# 5              258.0              754.0              901.0
# 6             2174.0            10183.0            12121.0

# %%
# Normalize Values
n_meta_topic_mapping = meta_topic_mapping.copy()

for col in ['Total Incidence', 'Epoch 1 Incidence', 'Epoch 2 Incidence', 'Epoch 3 Incidence']:
  n_meta_topic_mapping[col] = meta_topic_mapping[col].apply( lambda x : x / sum(meta_topic_mapping[col]))

n_meta_topic_mapping
# Out:
#                    Meta Topic Name  \
# 0                         Business
# 1    Cryptocurrencies & Investment
# 2  Technology, Industry & Business
# 3            Covid & Mobile Phones
# 4                   UK, Race, LGBT
# 5             Law & Current Events
# 6  Politics, News & Current Events
#
#                                               Topics  Total Incidence  \
# 0            [93, 65, 73, 60, 33, 124, 100, 98, 125]         0.033032
# 1  [118, 22, 90, 97, 53, 4, 52, 43, 123, 16, 56, 78]         0.127731
# 2  [117, 89, 7, 77, 105, 83, 80, 109, 17, 84, 122...         0.198294
# 3                               [86, 2, 11, 111, 69]         0.056869
# 4  [57, 76, 113, 66, 107, 20, 12, 112, 5, 106, 85...         0.146006
# 5                     [87, 42, 92, 103, 70, 104, 34]         0.031754
# 6  [101, 68, 61, 72, 65, 38, 32, 24, 1, 121, 59, ...         0.406314
#
#    Epoch 1 Incidence  Epoch 2 Incidence  Epoch 3 Incidence
# 0           0.051209           0.031303           0.030772
# 1           0.125420           0.126936           0.129041
# 2           0.191907           0.236477           0.161218
# 3           0.052552           0.064477           0.050152
# 4           0.170584           0.139450           0.147200
# 5           0.043318           0.027670           0.033323
# 6           0.365010           0.373688           0.448295

# %%
# Meta Topic Incidence Per Chat
E1_chats_metadata = chat_activity_epoch.filter(['Chat Name','Epoch 1 Freq'], axis=1).set_index('Chat Name')
E2_chats_metadata = chat_activity_epoch.filter(['Chat Name','Epoch 2 Freq'], axis=1).set_index('Chat Name')
E3_chats_metadata = chat_activity_epoch.filter(['Chat Name','Epoch 3 Freq'], axis=1).set_index('Chat Name')

ch_mtd = [E1_chats_metadata, E2_chats_metadata, E3_chats_metadata]


for chat in ch_names:
  i = 0
  for epoch in ['Epoch 1', 'Epoch 2', 'Epoch 3']:
    for mt_index, mt_row in meta_topic_mapping.iterrows():
      ch_mtd[i].loc[chat, 'Normalised ' + mt_row['Meta Topic Name']] = 0.0
      index_f = f'./Data/Messages/RawData/chat_{chat}_epoch_{epoch}.csv\n'
      for index, row in topics_per_class[topics_per_class["Class"] == index_f].iterrows():
        if row['Topic'] in mt_row['Topics']:
          ch_mtd[i].loc[chat, 'Normalised ' + mt_row['Meta Topic Name']] += row['Frequency'] 
      # Normalise by total frequency in that epoch
      ch_mtd[i].loc[chat, 'Normalised ' + mt_row['Meta Topic Name']] /= sum(chat_activity_epoch[epoch + ' Freq'])
    i += 1

# %%
for chat in ch_names:
  i = 0
  for epoch in ['Epoch 1', 'Epoch 2', 'Epoch 3']:
    ch_mtd[i].loc[chat, ch_mtd[i].columns != (epoch + ' Freq')] /= ch_mtd[i].loc[chat, ch_mtd[i].columns != (epoch + ' Freq')].sum()
    i += 1

# %%
meta_topic_mapping_c = meta_topic_mapping.copy()
columns_to_round = meta_topic_mapping_c.columns.drop(['Meta Topic Name', 'Topics'])

meta_topic_mapping_c[columns_to_round] = meta_topic_mapping[columns_to_round].round().astype(int)

cm = sns.light_palette("blue", as_cmap=True)

style_meta_topic_mapping_c = meta_topic_mapping_c.drop('Topics', axis=1).style.background_gradient(cmap=cm)

display(style_meta_topic_mapping_c)
# Out:
# <style type="text/css">
# #T_b859d_row0_col1, #T_b859d_row0_col4, #T_b859d_row5_col1, #T_b859d_row5_col2, #T_b859d_row5_col3 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_b859d_row0_col2 {
#   background-color: #ebebf3;
#   color: #000000;
# }
# #T_b859d_row0_col3, #T_b859d_row5_col4 {
#   background-color: #efeff3;
#   color: #000000;
# }
# #T_b859d_row1_col1, #T_b859d_row1_col2 {
#   background-color: #b3b3f6;
#   color: #000000;
# }
# #T_b859d_row1_col3 {
#   background-color: #acacf6;
#   color: #000000;
# }
# #T_b859d_row1_col4 {
#   background-color: #b8b8f6;
#   color: #000000;
# }
# #T_b859d_row2_col1 {
#   background-color: #8686f8;
#   color: #f1f1f1;
# }
# #T_b859d_row2_col2 {
#   background-color: #8181f8;
#   color: #f1f1f1;
# }
# #T_b859d_row2_col3 {
#   background-color: #5f5ffa;
#   color: #f1f1f1;
# }
# #T_b859d_row2_col4 {
#   background-color: #a6a6f7;
#   color: #000000;
# }
# #T_b859d_row3_col1 {
#   background-color: #e0e0f4;
#   color: #000000;
# }
# #T_b859d_row3_col2 {
#   background-color: #eaeaf3;
#   color: #000000;
# }
# #T_b859d_row3_col3 {
#   background-color: #d7d7f4;
#   color: #000000;
# }
# #T_b859d_row3_col4 {
#   background-color: #e6e6f3;
#   color: #000000;
# }
# #T_b859d_row4_col1 {
#   background-color: #a7a7f7;
#   color: #000000;
# }
# #T_b859d_row4_col2 {
#   background-color: #9191f8;
#   color: #f1f1f1;
# }
# #T_b859d_row4_col3 {
#   background-color: #a3a3f7;
#   color: #f1f1f1;
# }
# #T_b859d_row4_col4 {
#   background-color: #adadf6;
#   color: #000000;
# }
# #T_b859d_row6_col1, #T_b859d_row6_col2, #T_b859d_row6_col3, #T_b859d_row6_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b859d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b859d_level0_col0" class="col_heading level0 col0" >Meta Topic Name</th>
#       <th id="T_b859d_level0_col1" class="col_heading level0 col1" >Total Incidence</th>
#       <th id="T_b859d_level0_col2" class="col_heading level0 col2" >Epoch 1 Incidence</th>
#       <th id="T_b859d_level0_col3" class="col_heading level0 col3" >Epoch 2 Incidence</th>
#       <th id="T_b859d_level0_col4" class="col_heading level0 col4" >Epoch 3 Incidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b859d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b859d_row0_col0" class="data row0 col0" >Business</td>
#       <td id="T_b859d_row0_col1" class="data row0 col1" >1990</td>
#       <td id="T_b859d_row0_col2" class="data row0 col2" >305</td>
#       <td id="T_b859d_row0_col3" class="data row0 col3" >853</td>
#       <td id="T_b859d_row0_col4" class="data row0 col4" >832</td>
#     </tr>
#     <tr>
#       <th id="T_b859d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b859d_row1_col0" class="data row1 col0" >Cryptocurrencies & Investment</td>
#       <td id="T_b859d_row1_col1" class="data row1 col1" >7695</td>
#       <td id="T_b859d_row1_col2" class="data row1 col2" >747</td>
#       <td id="T_b859d_row1_col3" class="data row1 col3" >3459</td>
#       <td id="T_b859d_row1_col4" class="data row1 col4" >3489</td>
#     </tr>
#     <tr>
#       <th id="T_b859d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b859d_row2_col0" class="data row2 col0" >Technology, Industry & Business</td>
#       <td id="T_b859d_row2_col1" class="data row2 col1" >11946</td>
#       <td id="T_b859d_row2_col2" class="data row2 col2" >1143</td>
#       <td id="T_b859d_row2_col3" class="data row2 col3" >6444</td>
#       <td id="T_b859d_row2_col4" class="data row2 col4" >4359</td>
#     </tr>
#     <tr>
#       <th id="T_b859d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b859d_row3_col0" class="data row3 col0" >Covid & Mobile Phones</td>
#       <td id="T_b859d_row3_col1" class="data row3 col1" >3426</td>
#       <td id="T_b859d_row3_col2" class="data row3 col2" >313</td>
#       <td id="T_b859d_row3_col3" class="data row3 col3" >1757</td>
#       <td id="T_b859d_row3_col4" class="data row3 col4" >1356</td>
#     </tr>
#     <tr>
#       <th id="T_b859d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b859d_row4_col0" class="data row4 col0" >UK, Race, LGBT</td>
#       <td id="T_b859d_row4_col1" class="data row4 col1" >8796</td>
#       <td id="T_b859d_row4_col2" class="data row4 col2" >1016</td>
#       <td id="T_b859d_row4_col3" class="data row4 col3" >3800</td>
#       <td id="T_b859d_row4_col4" class="data row4 col4" >3980</td>
#     </tr>
#     <tr>
#       <th id="T_b859d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b859d_row5_col0" class="data row5 col0" >Law & Current Events</td>
#       <td id="T_b859d_row5_col1" class="data row5 col1" >1913</td>
#       <td id="T_b859d_row5_col2" class="data row5 col2" >258</td>
#       <td id="T_b859d_row5_col3" class="data row5 col3" >754</td>
#       <td id="T_b859d_row5_col4" class="data row5 col4" >901</td>
#     </tr>
#     <tr>
#       <th id="T_b859d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b859d_row6_col0" class="data row6 col0" >Politics, News & Current Events</td>
#       <td id="T_b859d_row6_col1" class="data row6 col1" >24478</td>
#       <td id="T_b859d_row6_col2" class="data row6 col2" >2174</td>
#       <td id="T_b859d_row6_col3" class="data row6 col3" >10183</td>
#       <td id="T_b859d_row6_col4" class="data row6 col4" >12121</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette("red", as_cmap=True)
style_n_meta_topic_mapping = n_meta_topic_mapping.drop('Topics', axis=1).style.background_gradient(cmap=cm)

display(style_n_meta_topic_mapping)
# Out:
# <style type="text/css">
# #T_ece6d_row0_col1, #T_ece6d_row0_col4, #T_ece6d_row5_col1, #T_ece6d_row5_col2, #T_ece6d_row5_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_ece6d_row0_col2 {
#   background-color: #f3eaea;
#   color: #000000;
# }
# #T_ece6d_row0_col3 {
#   background-color: #f3eeee;
#   color: #000000;
# }
# #T_ece6d_row1_col1, #T_ece6d_row1_col2 {
#   background-color: #f6b3b3;
#   color: #000000;
# }
# #T_ece6d_row1_col3 {
#   background-color: #f6abab;
#   color: #000000;
# }
# #T_ece6d_row1_col4 {
#   background-color: #f6b8b7;
#   color: #000000;
# }
# #T_ece6d_row2_col1 {
#   background-color: #f88686;
#   color: #f1f1f1;
# }
# #T_ece6d_row2_col2 {
#   background-color: #f88181;
#   color: #f1f1f1;
# }
# #T_ece6d_row2_col3 {
#   background-color: #fa5f5f;
#   color: #f1f1f1;
# }
# #T_ece6d_row2_col4 {
#   background-color: #f7a6a6;
#   color: #000000;
# }
# #T_ece6d_row3_col1 {
#   background-color: #f4e0e0;
#   color: #000000;
# }
# #T_ece6d_row3_col2 {
#   background-color: #f3e9e9;
#   color: #000000;
# }
# #T_ece6d_row3_col3 {
#   background-color: #f4d7d7;
#   color: #000000;
# }
# #T_ece6d_row3_col4 {
#   background-color: #f3e6e6;
#   color: #000000;
# }
# #T_ece6d_row4_col1 {
#   background-color: #f7a7a7;
#   color: #000000;
# }
# #T_ece6d_row4_col2 {
#   background-color: #f89191;
#   color: #000000;
# }
# #T_ece6d_row4_col3 {
#   background-color: #f7a3a3;
#   color: #000000;
# }
# #T_ece6d_row4_col4 {
#   background-color: #f6adad;
#   color: #000000;
# }
# #T_ece6d_row5_col4 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_ece6d_row6_col1, #T_ece6d_row6_col2, #T_ece6d_row6_col3, #T_ece6d_row6_col4 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ece6d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ece6d_level0_col0" class="col_heading level0 col0" >Meta Topic Name</th>
#       <th id="T_ece6d_level0_col1" class="col_heading level0 col1" >Total Incidence</th>
#       <th id="T_ece6d_level0_col2" class="col_heading level0 col2" >Epoch 1 Incidence</th>
#       <th id="T_ece6d_level0_col3" class="col_heading level0 col3" >Epoch 2 Incidence</th>
#       <th id="T_ece6d_level0_col4" class="col_heading level0 col4" >Epoch 3 Incidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ece6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ece6d_row0_col0" class="data row0 col0" >Business</td>
#       <td id="T_ece6d_row0_col1" class="data row0 col1" >0.033032</td>
#       <td id="T_ece6d_row0_col2" class="data row0 col2" >0.051209</td>
#       <td id="T_ece6d_row0_col3" class="data row0 col3" >0.031303</td>
#       <td id="T_ece6d_row0_col4" class="data row0 col4" >0.030772</td>
#     </tr>
#     <tr>
#       <th id="T_ece6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ece6d_row1_col0" class="data row1 col0" >Cryptocurrencies & Investment</td>
#       <td id="T_ece6d_row1_col1" class="data row1 col1" >0.127731</td>
#       <td id="T_ece6d_row1_col2" class="data row1 col2" >0.125420</td>
#       <td id="T_ece6d_row1_col3" class="data row1 col3" >0.126936</td>
#       <td id="T_ece6d_row1_col4" class="data row1 col4" >0.129041</td>
#     </tr>
#     <tr>
#       <th id="T_ece6d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ece6d_row2_col0" class="data row2 col0" >Technology, Industry & Business</td>
#       <td id="T_ece6d_row2_col1" class="data row2 col1" >0.198294</td>
#       <td id="T_ece6d_row2_col2" class="data row2 col2" >0.191907</td>
#       <td id="T_ece6d_row2_col3" class="data row2 col3" >0.236477</td>
#       <td id="T_ece6d_row2_col4" class="data row2 col4" >0.161218</td>
#     </tr>
#     <tr>
#       <th id="T_ece6d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ece6d_row3_col0" class="data row3 col0" >Covid & Mobile Phones</td>
#       <td id="T_ece6d_row3_col1" class="data row3 col1" >0.056869</td>
#       <td id="T_ece6d_row3_col2" class="data row3 col2" >0.052552</td>
#       <td id="T_ece6d_row3_col3" class="data row3 col3" >0.064477</td>
#       <td id="T_ece6d_row3_col4" class="data row3 col4" >0.050152</td>
#     </tr>
#     <tr>
#       <th id="T_ece6d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ece6d_row4_col0" class="data row4 col0" >UK, Race, LGBT</td>
#       <td id="T_ece6d_row4_col1" class="data row4 col1" >0.146006</td>
#       <td id="T_ece6d_row4_col2" class="data row4 col2" >0.170584</td>
#       <td id="T_ece6d_row4_col3" class="data row4 col3" >0.139450</td>
#       <td id="T_ece6d_row4_col4" class="data row4 col4" >0.147200</td>
#     </tr>
#     <tr>
#       <th id="T_ece6d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ece6d_row5_col0" class="data row5 col0" >Law & Current Events</td>
#       <td id="T_ece6d_row5_col1" class="data row5 col1" >0.031754</td>
#       <td id="T_ece6d_row5_col2" class="data row5 col2" >0.043318</td>
#       <td id="T_ece6d_row5_col3" class="data row5 col3" >0.027670</td>
#       <td id="T_ece6d_row5_col4" class="data row5 col4" >0.033323</td>
#     </tr>
#     <tr>
#       <th id="T_ece6d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ece6d_row6_col0" class="data row6 col0" >Politics, News & Current Events</td>
#       <td id="T_ece6d_row6_col1" class="data row6 col1" >0.406314</td>
#       <td id="T_ece6d_row6_col2" class="data row6 col2" >0.365010</td>
#       <td id="T_ece6d_row6_col3" class="data row6 col3" >0.373688</td>
#       <td id="T_ece6d_row6_col4" class="data row6 col4" >0.448295</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in range(3):
  ch_mtd[i] = ch_mtd[i].fillna(0.0)
  ch_mtd[i].to_csv(f'drive/MyDrive/LinkedInTheDark/MetaTopicAnal/meta_topics_epoch_{i+1}.csv')

n_meta_topic_mapping.to_csv('drive/MyDrive/LinkedInTheDark/MetaTopicAnal/meta_topics_mapping.csv')
